# %%
import pandas as pd

# %%
std_df = pd.read_csv("classmarks.csv", delimiter = ",")
std_df
# Out:
#    rollno  gender    group   age  math  english  urdu
# 0    MS01  female  group B  28.0  72.0       72  74.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 2    MS03  female  group B  21.0   NaN       95  93.0
# 3    MS04    male  group A  44.0  47.0       57  44.0
# 4    MS05    male  group C  54.0  76.0       78   NaN
# 5    MS06  female  group B   NaN  71.0       83  78.0
# 6    MS07  female  group B  47.0  88.0       95  92.0
# 7    MS08    male  group B  33.0  40.0       43  39.0
# 8    MS09    male  group D  27.0  64.0       64  67.0
# 9    MS10  female  group B  33.0  38.0       60  50.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 11   MS12    male  group D  53.0  40.0       52  43.0
# 12   MS13  female  group B  25.0  65.0       81  73.0
# 13   MS14    male  group A  26.0  78.0       72  70.0
# 14   MS15  female  group A  25.0  50.0       53  58.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# ...

# %%
std_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rollno   50 non-null     object
#  1   gender   50 non-null     object
#  2   group    50 non-null     object
#  3   age      47 non-null     float64
#  4   math     47 non-null     float64
#  5   english  50 non-null     int64
#  6   urdu     47 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 2.9+ KB

# %%
new_df = pd.read_csv('https://bit.ly/31eYGTx')
new_df
# Out:
#      Names  Age       Addr
# 0     Arif   50     Lahore
# 1     Rauf   52  Islamabad
# 2     Maaz   27   Peshawer
# 3   Hadeed   22  Islamabad
# 4  Mujahid   18    Karachi

# %%
new_df.head(2)
# Out:
#   Names  Age       Addr
# 0  Arif   50     Lahore
# 1  Rauf   52  Islamabad

# %%
new_df.columns
# Out:
# Index(['Names', 'Age', 'Addr'], dtype='object')

# %%
df2 = pd.read_csv('classmarks.csv', nrows = 10, usecols=['rollno', 'gender', 'age'])
df2
# Out:
#   rollno  gender   age
# 0   MS01  female  28.0
# 1   MS02  female  33.0
# 2   MS03  female  21.0
# 3   MS04    male  44.0
# 4   MS05    male  54.0
# 5   MS06  female   NaN
# 6   MS07  female  47.0
# 7   MS08    male  33.0
# 8   MS09    male  27.0
# 9   MS10  female  33.0

# %%
sheet_id = '1H9ZTGVRXN3zuyP3cbJQnbX7JlqhqFNMOE_WwDP-PRTE'
sheet_num = 'sheet1'
url = 'https://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}'.format(sheet_id, sheet_num)

df3 = pd.read_csv(url, nrows = 15, usecols = ['rollno', 'age', 'gender'])
df3
# Out:
#    rollno  gender   age
# 0    MS01  female  28.0
# 1    MS02  female  33.0
# 2    MS03  female  21.0
# 3    MS04    male  44.0
# 4    MS05    male  54.0
# 5    MS06  female   NaN
# 6    MS07  female  47.0
# 7    MS08    male  33.0
# 8    MS09    male  27.0
# 9    MS10  female  33.0
# 10   MS11    male  46.0
# 11   MS12    male  53.0
# 12   MS13  female  25.0
# 13   MS14    male  26.0
# 14   MS15  female  25.0

# %%
std_df = pd.read_csv('classmarks.csv')
std_df.head()
# Out:
#   rollno  gender    group   age  math  english  urdu
# 0   MS01  female  group B  28.0  72.0       72  74.0
# 1   MS02  female  group C  33.0  69.0       90  88.0
# 2   MS03  female  group B  21.0   NaN       95  93.0
# 3   MS04    male  group A  44.0  47.0       57  44.0
# 4   MS05    male  group C  54.0  76.0       78   NaN

# %%
male_gen = (std_df['gender'] == 'male')
male_gen

newDfForMale = std_df.loc[male_gen]
newDfForMale
# Out:
#    rollno gender    group   age  math  english  urdu
# 3    MS04   male  group A  44.0  47.0       57  44.0
# 4    MS05   male  group C  54.0  76.0       78   NaN
# 7    MS08   male  group B  33.0  40.0       43  39.0
# 8    MS09   male  group D  27.0  64.0       64  67.0
# 10   MS11   male  group C  46.0  58.0       54  52.0
# 11   MS12   male  group D  53.0  40.0       52  43.0
# 13   MS14   male  group A  26.0  78.0       72  70.0
# 16   MS17   male  group C  22.0  88.0       89  86.0
# 18   MS19   male  group C  33.0  46.0       42  46.0
# 20   MS21   male  group D  34.0  66.0       69  63.0
# 22   MS23   male  group D  31.0  44.0       54  53.0
# 24   MS25   male  group D  33.0  74.0       71  80.0
# 25   MS26   male  group A  39.0  73.0       74  72.0
# 26   MS27   male  group B   NaN  69.0       54  55.0
# 28   MS29   male  group C  44.0  70.0       70  65.0
# 33   MS34   male  group D  34.0  40.0       42  38.0
# 34   MS35   male  group E  45.0  97.0       87  82.0
# ...

# %%
pass_eng = (std_df['english'] > 60)

newDfEng = std_df.loc[pass_eng] #mask to filter out people having score of english greater than 60
newDfEng.info()
newDfEng.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rollno   34 non-null     object
#  1   gender   34 non-null     object
#  2   group    34 non-null     object
#  3   age      32 non-null     float64
#  4   math     32 non-null     float64
#  5   english  34 non-null     int64
#  6   urdu     32 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 2.1+ KB
# (34, 7)

# %%
newDfEng.to_csv('englishmarks.csv', index = False)

n = pd.read_csv('englishmarks.csv')
n
# Out:
#    rollno  gender    group   age  math  english  urdu
# 0    MS01  female  group B  28.0  72.0       72  74.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 2    MS03  female  group B  21.0   NaN       95  93.0
# 3    MS05    male  group C  54.0  76.0       78   NaN
# 4    MS06  female  group B   NaN  71.0       83  78.0
# 5    MS07  female  group B  47.0  88.0       95  92.0
# 6    MS09    male  group D  27.0  64.0       64  67.0
# 7    MS13  female  group B  25.0  65.0       81  73.0
# 8    MS14    male  group A  26.0  78.0       72  70.0
# 9    MS16  female  group C  29.0  69.0       75  78.0
# 10   MS17    male  group C  22.0  88.0       89  86.0
# 11   MS21    male  group D  34.0  66.0       69  63.0
# 12   MS22  female  group B  32.0  65.0       75  70.0
# 13   MS24  female  group C  37.0   NaN       73  73.0
# 14   MS25    male  group D  33.0  74.0       71  80.0
# 15   MS26    male  group A  39.0  73.0       74  72.0
# ...

# %%
df_js = pd.read_json('newrecord.json', lines = True)
df_js
# Out:
#      name  age grade
# 0   Kamal   12     A
# 1  Hashim   18     B
# 2  Salman   11     A
# 3  Mazhar   12     C
# 4   Eisha   13     B
# 5  Farhan   22     C
# 6  Mohsin   11     A
# 7   Bilal   19     A
# 8  Ishaan   10     D
# 9  Zalaid    9     B

# %%
onlyA = df_js.loc[df_js['age'] > 10]
onlyA
# Out:
#      name  age grade
# 0   Kamal   12     A
# 1  Hashim   18     B
# 2  Salman   11     A
# 3  Mazhar   12     C
# 4   Eisha   13     B
# 5  Farhan   22     C
# 6  Mohsin   11     A
# 7   Bilal   19     A

# %%
std_df
# Out:
#    rollno  gender    group   age  math  english  urdu
# 0    MS01  female  group B  28.0  72.0       72  74.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 2    MS03  female  group B  21.0   NaN       95  93.0
# 3    MS04    male  group A  44.0  47.0       57  44.0
# 4    MS05    male  group C  54.0  76.0       78   NaN
# 5    MS06  female  group B   NaN  71.0       83  78.0
# 6    MS07  female  group B  47.0  88.0       95  92.0
# 7    MS08    male  group B  33.0  40.0       43  39.0
# 8    MS09    male  group D  27.0  64.0       64  67.0
# 9    MS10  female  group B  33.0  38.0       60  50.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 11   MS12    male  group D  53.0  40.0       52  43.0
# 12   MS13  female  group B  25.0  65.0       81  73.0
# 13   MS14    male  group A  26.0  78.0       72  70.0
# 14   MS15  female  group A  25.0  50.0       53  58.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# ...

# %%
mask = (std_df['group'] == 'group C')
grp_c = std_df.loc[mask]
grp_c
# Out:
#    rollno  gender    group   age  math  english  urdu
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 4    MS05    male  group C  54.0  76.0       78   NaN
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 49   MS50    male  group C  37.0  66.0       78  81.0

# %%
grp_c.to_csv('only_c_grp.csv', index = False)

# %%
grp_c.dtypes
# Out:
# rollno      object
# gender      object
# group       object
# age        float64
# math       float64
# english      int64
# urdu       float64
# dtype: object

# %%
std_df.describe(include = 'all')
# Out:
#        rollno  gender    group        age       math    english       urdu
# count      50      50       50  47.000000  47.000000  50.000000  47.000000
# unique     50       2        5        NaN        NaN        NaN        NaN
# top      MS01  female  group B        NaN        NaN        NaN        NaN
# freq        1      27       15        NaN        NaN        NaN        NaN
# mean      NaN     NaN      NaN  34.276596  62.063830  67.820000  66.000000
# std       NaN     NaN      NaN   7.886979  14.700494  14.148902  14.960818
# min       NaN     NaN      NaN  21.000000  18.000000  32.000000  28.000000
# 25%       NaN     NaN      NaN  28.500000  54.500000  57.250000  56.000000
# 50%       NaN     NaN      NaN  33.000000  65.000000  70.000000  67.000000
# 75%       NaN     NaN      NaN  38.500000  70.500000  75.000000  76.000000
# max       NaN     NaN      NaN  54.000000  97.000000  95.000000  93.000000

# %%
newLabels = ['Roll_num', 'Gender', 'Group', 'Age', 'Maths', 'English', 'Urdu']
grp_c.columns = newLabels

grp_c
# Out:
#    Roll_num  Gender    Group   Age  Maths  English  Urdu
# 1      MS02  female  group C  33.0   69.0       90  88.0
# 4      MS05    male  group C  54.0   76.0       78   NaN
# 10     MS11    male  group C  46.0   58.0       54  52.0
# 15     MS16  female  group C  29.0   69.0       75  78.0
# 16     MS17    male  group C  22.0   88.0       89  86.0
# 18     MS19    male  group C  33.0   46.0       42  46.0
# 19     MS20  female  group C  36.0   54.0       58   NaN
# 23     MS24  female  group C  37.0    NaN       73  73.0
# 27     MS28  female  group C  47.0   67.0       69  75.0
# 28     MS29    male  group C  44.0   70.0       70  65.0
# 40     MS41    male  group C  35.0   55.0       61  54.0
# 41     MS42  female  group C  22.0   58.0       73  68.0
# 47     MS48  female  group C  30.0   66.0       71  76.0
# 49     MS50    male  group C  37.0   66.0       78  81.0

# %%
grp_c.rename(columns={'Roll_num': 'Roll_No'}, inplace = False)
# Out:
#    Roll_No  Gender    Group   Age  Maths  English  Urdu
# 1     MS02  female  group C  33.0   69.0       90  88.0
# 4     MS05    male  group C  54.0   76.0       78   NaN
# 10    MS11    male  group C  46.0   58.0       54  52.0
# 15    MS16  female  group C  29.0   69.0       75  78.0
# 16    MS17    male  group C  22.0   88.0       89  86.0
# 18    MS19    male  group C  33.0   46.0       42  46.0
# 19    MS20  female  group C  36.0   54.0       58   NaN
# 23    MS24  female  group C  37.0    NaN       73  73.0
# 27    MS28  female  group C  47.0   67.0       69  75.0
# 28    MS29    male  group C  44.0   70.0       70  65.0
# 40    MS41    male  group C  35.0   55.0       61  54.0
# 41    MS42  female  group C  22.0   58.0       73  68.0
# 47    MS48  female  group C  30.0   66.0       71  76.0
# 49    MS50    male  group C  37.0   66.0       78  81.0

# %%
std_df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
grp_c.set_index(keys = 'Roll_num', drop = True, inplace = True)

# %%
grp_c.reset_index()
# Out:
#    Roll_num  Gender    Group   Age  Maths  English  Urdu
# 0      MS02  female  group C  33.0   69.0       90  88.0
# 1      MS05    male  group C  54.0   76.0       78   NaN
# 2      MS11    male  group C  46.0   58.0       54  52.0
# 3      MS16  female  group C  29.0   69.0       75  78.0
# 4      MS17    male  group C  22.0   88.0       89  86.0
# 5      MS19    male  group C  33.0   46.0       42  46.0
# 6      MS20  female  group C  36.0   54.0       58   NaN
# 7      MS24  female  group C  37.0    NaN       73  73.0
# 8      MS28  female  group C  47.0   67.0       69  75.0
# 9      MS29    male  group C  44.0   70.0       70  65.0
# 10     MS41    male  group C  35.0   55.0       61  54.0
# 11     MS42  female  group C  22.0   58.0       73  68.0
# 12     MS48  female  group C  30.0   66.0       71  76.0
# 13     MS50    male  group C  37.0   66.0       78  81.0

# %%
std_df.describe()
# Out:
#              age       math    english       urdu
# count  47.000000  47.000000  50.000000  47.000000
# mean   34.276596  62.063830  67.820000  66.000000
# std     7.886979  14.700494  14.148902  14.960818
# min    21.000000  18.000000  32.000000  28.000000
# 25%    28.500000  54.500000  57.250000  56.000000
# 50%    33.000000  65.000000  70.000000  67.000000
# 75%    38.500000  70.500000  75.000000  76.000000
# max    54.000000  97.000000  95.000000  93.000000

# %%
grp_c
# Out:
#     index Roll_num  Gender    Group   Age  Maths  English  Urdu
# 0       0     MS02  female  group C  33.0   69.0       90  88.0
# 1       1     MS05    male  group C  54.0   76.0       78   NaN
# 2       2     MS11    male  group C  46.0   58.0       54  52.0
# 3       3     MS16  female  group C  29.0   69.0       75  78.0
# 4       4     MS17    male  group C  22.0   88.0       89  86.0
# 5       5     MS19    male  group C  33.0   46.0       42  46.0
# 6       6     MS20  female  group C  36.0   54.0       58   NaN
# 7       7     MS24  female  group C  37.0    NaN       73  73.0
# 8       8     MS28  female  group C  47.0   67.0       69  75.0
# 9       9     MS29    male  group C  44.0   70.0       70  65.0
# 10     10     MS41    male  group C  35.0   55.0       61  54.0
# 11     11     MS42  female  group C  22.0   58.0       73  68.0
# 12     12     MS48  female  group C  30.0   66.0       71  76.0
# 13     13     MS50    male  group C  37.0   66.0       78  81.0

# %%
grp_c.reset_index(inplace = True, drop = True)
grp_c
# Out:
#     index Roll_num  Gender    Group   Age  Maths  English  Urdu
# 0       0     MS02  female  group C  33.0   69.0       90  88.0
# 1       1     MS05    male  group C  54.0   76.0       78   NaN
# 2       2     MS11    male  group C  46.0   58.0       54  52.0
# 3       3     MS16  female  group C  29.0   69.0       75  78.0
# 4       4     MS17    male  group C  22.0   88.0       89  86.0
# 5       5     MS19    male  group C  33.0   46.0       42  46.0
# 6       6     MS20  female  group C  36.0   54.0       58   NaN
# 7       7     MS24  female  group C  37.0    NaN       73  73.0
# 8       8     MS28  female  group C  47.0   67.0       69  75.0
# 9       9     MS29    male  group C  44.0   70.0       70  65.0
# 10     10     MS41    male  group C  35.0   55.0       61  54.0
# 11     11     MS42  female  group C  22.0   58.0       73  68.0
# 12     12     MS48  female  group C  30.0   66.0       71  76.0
# 13     13     MS50    male  group C  37.0   66.0       78  81.0

# %%
grp_c = std_df.loc[mask]

# %%
grp_c_sort = grp_c.sort_values('age')
grp_c_sort
# Out:
#    rollno  gender    group   age  math  english  urdu
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 49   MS50    male  group C  37.0  66.0       78  81.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 4    MS05    male  group C  54.0  76.0       78   NaN

# %%
grp_c_sort.loc[:1]
# Out:
#    rollno  gender    group   age  math  english  urdu
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 1    MS02  female  group C  33.0  69.0       90  88.0

# %%
grp_c_sort
# Out:
#    rollno  gender    group   age  math  english  urdu
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 49   MS50    male  group C  37.0  66.0       78  81.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 4    MS05    male  group C  54.0  76.0       78   NaN

# %%
grp_c_sort.reset_index(inplace = True)

# %%
grp_c_sort.set_index(keys='index', inplace = True)

# %%
grp_c_sort
# Out:
#    rollno  gender    group   age  math  english  urdu
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 49   MS50    male  group C  37.0  66.0       78  81.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 4    MS05    male  group C  54.0  76.0       78   NaN

# %%
grp_c_sort.iloc[[2,4,6],:]
# Out:
#    rollno  gender    group   age  math  english  urdu
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 40   MS41    male  group C  35.0  55.0       61  54.0

# %%
#grp_c.iloc[[0,1,5],[2,4,5]]
grp_c.iloc[0:4, 5:]
# Out:
#     english  urdu
# 1        90  88.0
# 4        78   NaN
# 10       54  52.0
# 15       75  78.0

# %%
grp_c
# Out:
#    rollno  gender    group   age  math  english  urdu
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 4    MS05    male  group C  54.0  76.0       78   NaN
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 49   MS50    male  group C  37.0  66.0       78  81.0

# %%
grp_c.iloc[4,3]
# Out:
# 22.0

# %%
grp_c.loc[:,'rollno':'age']
# Out:
#    rollno  gender    group   age
# 1    MS02  female  group C  33.0
# 4    MS05    male  group C  54.0
# 10   MS11    male  group C  46.0
# 15   MS16  female  group C  29.0
# 16   MS17    male  group C  22.0
# 18   MS19    male  group C  33.0
# 19   MS20  female  group C  36.0
# 23   MS24  female  group C  37.0
# 27   MS28  female  group C  47.0
# 28   MS29    male  group C  44.0
# 40   MS41    male  group C  35.0
# 41   MS42  female  group C  22.0
# 47   MS48  female  group C  30.0
# 49   MS50    male  group C  37.0

# %%
grp_c_sort.loc[grp_c_sort.age > 40]
# Out:
#    rollno  gender    group   age  math  english  urdu
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 4    MS05    male  group C  54.0  76.0       78   NaN

# %%
grp_c_sort
# Out:
#    rollno  gender    group   age  math  english  urdu
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 49   MS50    male  group C  37.0  66.0       78  81.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 4    MS05    male  group C  54.0  76.0       78   NaN

# %%
grp_c
# Out:
#    rollno  gender    group   age  math  english  urdu
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 4    MS05    male  group C  54.0  76.0       78   NaN
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 49   MS50    male  group C  37.0  66.0       78  81.0

# %%
grp_c_sort.select_dtypes('float64')
# Out:
#      age  math  urdu
# 16  22.0  88.0  86.0
# 41  22.0  58.0  68.0
# 15  29.0  69.0  78.0
# 47  30.0  66.0  76.0
# 1   33.0  69.0  88.0
# 18  33.0  46.0  46.0
# 40  35.0  55.0  54.0
# 19  36.0  54.0   NaN
# 23  37.0   NaN  73.0
# 49  37.0  66.0  81.0
# 28  44.0  70.0  65.0
# 10  46.0  58.0  52.0
# 27  47.0  67.0  75.0
# 4   54.0  76.0   NaN

# %%
grp_c
# Out:
#    rollno  gender    group   age  math  english  urdu
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 4    MS05    male  group C  54.0  76.0       78   NaN
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 49   MS50    male  group C  37.0  66.0       78  81.0

# %%
grp_c_sort.groupby('age').get_group(22).english.max()
# Out:
# 89

# %%
grp_c['english']
# Out:
# 1     90
# 4     78
# 10    54
# 15    75
# 16    89
# 18    42
# 19    58
# 23    73
# 27    69
# 28    70
# 40    61
# 41    73
# 47    71
# 49    78
# Name: english, dtype: int64

# %%
g = grp_c_sort.loc[(grp_c_sort.gender == 'female') & (grp_c_sort.age > 35)]
g
# Out:
#    rollno  gender    group   age  math  english  urdu
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 27   MS28  female  group C  47.0  67.0       69  75.0

# %%
grp_c_sort.columns
# Out:
# Index(['rollno', 'gender', 'group', 'age', 'math', 'english', 'urdu'], dtype='object')

# %%
l2 = [x.upper() for x in grp_c_sort.columns]

grp_c_sort.columns = l2
grp_c_sort
# Out:
#    ROLLNO  GENDER    GROUP   AGE  MATH  ENGLISH  URDU
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 41   MS42  female  group C  22.0  58.0       73  68.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# 47   MS48  female  group C  30.0  66.0       71  76.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 18   MS19    male  group C  33.0  46.0       42  46.0
# 40   MS41    male  group C  35.0  55.0       61  54.0
# 19   MS20  female  group C  36.0  54.0       58   NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0
# 49   MS50    male  group C  37.0  66.0       78  81.0
# 28   MS29    male  group C  44.0  70.0       70  65.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 27   MS28  female  group C  47.0  67.0       69  75.0
# 4    MS05    male  group C  54.0  76.0       78   NaN

# %%
grp_c_sort.head(3)
# Out:
#    ROLLNO  GENDER    GROUP   AGE  MATH  ENGLISH  URDU
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 41   MS42  female  group C  22.0  60.0       75  68.0
# 15   MS16  female  group C  29.0  69.0       75  78.0

# %%
grp_c_sort.loc[grp_c_sort.ROLLNO == 'MS42', ['MATH','ENGLISH']] = [59, 74]
grp_c_sort.head(3)
# Out:
#    ROLLNO  GENDER    GROUP   AGE  MATH  ENGLISH  URDU
# 16   MS17    male  group C  22.0  88.0       89  86.0
# 41   MS42  female  group C  22.0  59.0       74  68.0
# 15   MS16  female  group C  29.0  69.0       75  78.0

# %%
l2 = [x.lower() for x in grp_c_sort]
grp_c_sort.columns = l2

# %%
def showAge(x):
    if(x < 35):
        return "Young"
    else:
        return "Old"

# %%
grp_c_sort['age'].map(showAge)
# Out:
# 16    Young
# 41    Young
# 15    Young
# 47    Young
# 1     Young
# 18    Young
# 40      Old
# 19      Old
# 23      Old
# 49      Old
# 28      Old
# 10      Old
# 27      Old
# 4       Old
# Name: age, dtype: object

# %%
grp_c_sort['age'].map(lambda x: "Young" if x <35 else "Old")
# Out:
# 16    Young
# 41    Young
# 15    Young
# 47    Young
# 1     Young
# 18    Young
# 40      Old
# 19      Old
# 23      Old
# 49      Old
# 28      Old
# 10      Old
# 27      Old
# 4       Old
# Name: age, dtype: object

# %%
grp_c_sort['gender'].replace({'M':'male', 'F':'female'},inplace = True)

# %%
grp_c_sort
# Out:
#    rollno  gender    group   age  math  english  urdu  totalmarks
# 16   MS17    male  group C  22.0  88.0       89  86.0       263.0
# 41   MS42  female  group C  22.0  59.0       74  68.0       201.0
# 15   MS16  female  group C  29.0  69.0       75  78.0       222.0
# 47   MS48  female  group C  30.0  66.0       71  76.0       213.0
# 1    MS02  female  group C  33.0  69.0       90  88.0       247.0
# 18   MS19    male  group C  33.0  46.0       42  46.0       134.0
# 40   MS41    male  group C  35.0  55.0       61  54.0       170.0
# 19   MS20  female  group C  36.0  54.0       58   NaN         NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0         NaN
# 49   MS50    male  group C  37.0  66.0       78  81.0       225.0
# 28   MS29    male  group C  44.0  70.0       70  65.0       205.0
# 10   MS11    male  group C  46.0  58.0       54  52.0       164.0
# 27   MS28  female  group C  47.0  67.0       69  75.0       211.0
# ...

# %%
grp_c_sort['gender'].apply(len)
# Out:
# 16    4
# 41    6
# 15    6
# 47    6
# 1     6
# 18    4
# 40    4
# 19    6
# 23    6
# 49    4
# 28    4
# 10    4
# 27    6
# 4     4
# Name: gender, dtype: int64

# %%
t_marks = grp_c_sort.math + grp_c_sort.english + grp_c_sort.urdu

# %%
grp_c_sort['totalmarks'] = t_marks

# %%
grp_c_sort['average'] = t_marks/3
grp_c_sort
# Out:
#    rollno  gender    group   age  math  english  urdu  totalmarks    average
# 16   MS17    male  group C  22.0  88.0       89  86.0       263.0  87.666667
# 41   MS42  female  group C  22.0  59.0       74  68.0       201.0  67.000000
# 15   MS16  female  group C  29.0  69.0       75  78.0       222.0  74.000000
# 47   MS48  female  group C  30.0  66.0       71  76.0       213.0  71.000000
# 1    MS02  female  group C  33.0  69.0       90  88.0       247.0  82.333333
# 18   MS19    male  group C  33.0  46.0       42  46.0       134.0  44.666667
# 40   MS41    male  group C  35.0  55.0       61  54.0       170.0  56.666667
# 19   MS20  female  group C  36.0  54.0       58   NaN         NaN        NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0         NaN        NaN
# 49   MS50    male  group C  37.0  66.0       78  81.0       225.0  75.000000
# 28   MS29    male  group C  44.0  70.0       70  65.0       205.0  68.333333
# ...

# %%
grp_c_sort
# Out:
#    rollno  gender    group   age  math  english  urdu  totalmarks
# 16   MS17    male  group C  22.0  88.0       89  86.0       263.0
# 41   MS42  female  group C  22.0  59.0       74  68.0       201.0
# 15   MS16  female  group C  29.0  69.0       75  78.0       222.0
# 47   MS48  female  group C  30.0  66.0       71  76.0       213.0
# 1    MS02  female  group C  33.0  69.0       90  88.0       247.0
# 18   MS19    male  group C  33.0  46.0       42  46.0       134.0
# 40   MS41    male  group C  35.0  55.0       61  54.0       170.0
# 19   MS20  female  group C  36.0  54.0       58   NaN         NaN
# 23   MS24  female  group C  37.0   NaN       73  73.0         NaN
# 49   MS50    male  group C  37.0  66.0       78  81.0       225.0
# 28   MS29    male  group C  44.0  70.0       70  65.0       205.0
# 10   MS11    male  group C  46.0  58.0       54  52.0       164.0
# 27   MS28  female  group C  47.0  67.0       69  75.0       211.0
# ...
