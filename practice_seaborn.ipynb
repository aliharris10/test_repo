# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
mks = np.array([65, 85, 72,45, 87, 68, 61, 80, 77, 73, 66])
fig, ax = plt.subplots()
nms = np.arange(0,100,1)
ax.boxplot(x = mks, patch_artist = True)

ax.yaxis.grid(True)
ax.set_title("Marks of Students in Programming")
ax.set_xlabel("Programming")
ax.set_ylabel("Marks")
q1, q2, q3 = np.quantile(mks, [.25, .5, .75])
print(mks.min())
print(mks.max())
print(q1)
print(q2)
print(q3)
# Out:
# 45
# 87
# 65.5
# 72.0
# 78.5

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2)

# %%
import pandas as pd
df = pd.read_csv('iris31.csv')

# %%
df.rename(columns = {'Sepal.Length': 'sepal_length', 'Sepal.Width': 'sepal_width', 
                     'Petal.Length': 'petal_length', 'Petal.Width': 'petal_width', 'Species': 'species'}, inplace = True)

# %%
#df.petal_length[149] = 0.0
#df.petal_length.fillna(method = 'bfill', inplace = True)
df.petal_length.isna().value_counts()
# Out:
# False    150
# Name: petal_length, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data = np.random.randn(200)

# %%
fig, ax = plt.subplots(2, 2, squeeze = False, figsize = (20,6))

ax[0][0].plot(df.index, df['sepal_length'])
ax[0][1].bar(df.index, df['sepal_length'], color = 'g')
ax[1][0].scatter(df['sepal_length'], df['sepal_width'], color = 'r')
ax[1][1].hist(df['petal_length'], bins = 10, color = 'y')
# Out:
# (array([ 1., 11., 39.,  0.,  3., 16., 30., 25., 19.,  6.]),
#  array([0.  , 0.69, 1.38, 2.07, 2.76, 3.45, 4.14, 4.83, 5.52, 6.21, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.4           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           0.0          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x = 'sepal_width', y = 'sepal_length', data = df, kind = 'line');

# %%
sns.relplot(x = 'sepal_width', y = 'sepal_length', data = df, kind = 'line', style = 'species', hue = 'species');

# %%
sns.relplot(x = 'sepal_width', y = 'sepal_length', data = df, kind = 'line', hue = 'species', col = 'species');
