# %%
import pandas as pd

# %%
titanic_df = pd.read_csv('titanic3.csv')
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_df = pd.read_csv('titanic3.csv')

# %%
fortune_df = pd.read_csv('fortune500.csv')
fortune_df
# Out:
#        Year  Rank                Company  Revenue (in millions)  \
# 0      1955     1         General Motors                 9823.5
# 1      1955     2            Exxon Mobil                 5661.4
# 2      1955     3             U.S. Steel                 3250.4
# 3      1955     4       General Electric                 2959.1
# 4      1955     5                 Esmark                 2510.8
# ...     ...   ...                    ...                    ...
# 25495  2005   496        Wm. Wrigley Jr.                 3648.6
# 25496  2005   497         Peabody Energy                 3631.6
# 25497  2005   498  Wendy's International                 3630.4
# 25498  2005   499     Kindred Healthcare                 3616.6
# 25499  2005   500   Cincinnati Financial                 3614.0
#
#       Profit (in millions)
# 0                      806
# 1                    584.8
# 2                    195.4
# 3                    212.6
# 4                     19.1
# ...                    ...
# ...

# %%
imdb_df = pd.read_csv('imdb_dataset.csv')
imdb_df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
covid_df = pd.read_csv('covid_contry_wise.csv')
covid_df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
pd.set_option('min_rows', 20)

# %%
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1299       3         0                              Yasbeck, Mr. Antoni
# ...

# %%
pd.get_option('max_row')
# Out:
# 100

# %%
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1299       3         0                              Yasbeck, Mr. Antoni
# ...

# %%
imdb_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     review  \
# ...

# %%
pd.get_option('display.max_colwidth')
# Out:
# 500

# %%
pd.set_option('display.max_colwidth', 500)

# %%
pd.reset_option('all')
# Out:
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# C:\Users\Ali Harris\anaconda3\lib\site-packages\pandas\_config\config.py:630: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   warnings.warn(d.msg, FutureWarning)
# C:\Users\Ali Harris\anaconda3\lib\site-packages\pandas\_config\config.py:630: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
# ...

# %%
pd.get_option('display.max_colwidth')
# Out:
# 50

# %%
pd.get_option('max_row') #60
pd.get_option('min_row') #10
# Out:
# 10

# %%
list_names = ['Ali', 'Zaib', 'Saad', 'Umair', 'Hamza', 'Abdullah']
list_ind = ['a', 'z', 's', 'u', 'h', 'a']

n = pd.Series(data = list_names, index = list_ind, name = 'mynames')

# %%
n
# Out:
# a         Ali
# z        Zaib
# s        Saad
# u       Umair
# h       Hamza
# a    Abdullah
# Name: mynames, dtype: object

# %%
n['a']
# Out:
# a         Ali
# a    Abdullah
# dtype: object

# %%
print(type(n))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(n)
# Out:
# a         Ali
# z        Zaib
# s        Saad
# u       Umair
# h       Hamza
# a    Abdullah
# Name: mynames, dtype: object

# %%
n.name
# Out:
# 'mynames'

# %%
n.index
# Out:
# Index(['a', 'z', 's', 'u', 'h', 'a'], dtype='object')

# %%
n.values
# Out:
# array(['Ali', 'Zaib', 'Saad', 'Umair', 'Hamza', 'Abdullah'], dtype=object)

# %%
n.shape
# Out:
# (6,)

# %%
print(n)
# Out:
# a         Ali
# z        Zaib
# s        Saad
# u       Umair
# h       Hamza
# a    Abdullah
# Name: mynames, dtype: object

# %%
print(n)
print(n.index)
# Out:
# a         Ali
# z        Zaib
# s        Saad
# u       Umair
# h       Hamza
# a    Abdullah
# Name: mynames, dtype: object
# Index(['a', 'z', 's', 'u', 'h', 'a'], dtype='object')

# %%
import numpy as np
my_dict = {0:"Rauf", 1:np.nan, 2:"Maaz", 3:"Hadeed", 4:"Mujahid", 5:"Mohid", 6:"Jamil"}
sam = pd.Series(my_dict, name="myseries1")
sam
# Out:
# 0       Rauf
# 1        NaN
# 2       Maaz
# 3     Hadeed
# 4    Mujahid
# 5      Mohid
# 6      Jamil
# Name: myseries1, dtype: object

# %%
sam.hasnans
# Out:
# True

# %%
sam.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
print(sam)
print(sam.index)
# Out:
# 0       Rauf
# 1        NaN
# 2       Maaz
# 3     Hadeed
# 4    Mujahid
# 5      Mohid
# 6      Jamil
# Name: myseries1, dtype: object
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
n_list = ['Ahmad', 'Asad', 'Qadir', 'Amir', 'Javaid', 'Sami', 'Pervaiz']

n_l = pd.Series(data = n_list)
print(n_l)
# Out:
# 0      Ahmad
# 1       Asad
# 2      Qadir
# 3       Amir
# 4     Javaid
# 5       Sami
# 6    Pervaiz
# dtype: object

# %%
print(n_l.index)
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
r_list = np.random.randint(low = 100, high = 150, size = 7)

n_l = pd.Series(data = n_list, index = r_list)

n_l
# Out:
# 102      Ahmad
# 112       Asad
# 132      Qadir
# 146       Amir
# 127     Javaid
# 134       Sami
# 115    Pervaiz
# dtype: object

# %%
print(n)
# Out:
# a         Ali
# z        Zaib
# s        Saad
# u       Umair
# h       Hamza
# a    Abdullah
# Name: mynames, dtype: object

# %%
n['a']
# Out:
# a         Ali
# a    Abdullah
# Name: mynames, dtype: object

# %%
n.loc['u']
# Out:
# 'Umair'

# %%
n.iloc[0]
# Out:
# 'Ali'

# %%
n_l.loc[146]
# Out:
# 'Amir'

# %%
n_l.iloc[[1,3]]
# Out:
# 112    Asad
# 146    Amir
# dtype: object

# %%
n.loc[['a','s','u']]
# Out:
# a         Ali
# a    Abdullah
# s        Saad
# u       Umair
# Name: mynames, dtype: object

# %%
n.iloc[[2,3,4]]
# Out:
# s     Saad
# u    Umair
# h    Hamza
# Name: mynames, dtype: object

# %%
n_l[:4]
# Out:
# 102    Ahmad
# 112     Asad
# 132    Qadir
# 146     Amir
# dtype: object

# %%
print(n_l.loc[102:146])
print(n_l.iloc[2:])
# Out:
# 102    Ahmad
# 112     Asad
# 132    Qadir
# 146     Amir
# dtype: object
# 132      Qadir
# 146       Amir
# 127     Javaid
# 134       Sami
# 115    Pervaiz
# dtype: object

# %%
n.iloc[1::2]
# Out:
# z        Zaib
# u       Umair
# a    Abdullah
# Name: mynames, dtype: object

# %%
dict = {
    "name": pd.Series(['Asad', 'Hamid', 'Mubashir0', 'Saad'], index=['a','b','c', 'd']),
    "age": pd.Series([30, np.nan,25, 17], index=['a','x','y','d']),
    "addr": pd.Series(['Lahore', 'Multan',''], index=['a', 'd', 'x']),
}

peoples = pd.DataFrame(data = dict)

# %%
peoples
# Out:
#         name   age    addr
# a       Asad  30.0  Lahore
# b      Hamid   NaN     NaN
# c  Mubashir0   NaN     NaN
# d       Saad  17.0  Multan
# x        NaN   NaN
# y        NaN  25.0     NaN

# %%
peoples.head(-2)
# Out:
#         name   age    addr
# a       Asad  30.0  Lahore
# b      Hamid   NaN     NaN
# c  Mubashir0   NaN     NaN
# d       Saad  17.0  Multan

# %%
peoples.tail(-3)
# Out:
#    name   age    addr
# d  Saad  17.0  Multan
# x   NaN   NaN
# y   NaN  25.0     NaN

# %%
peoples.shape
# Out:
# (6, 3)

# %%
peoples.columns
# Out:
# Index(['name', 'age', 'addr'], dtype='object')

# %%
peoples.dtypes
# Out:
# name     object
# age     float64
# addr     object
# dtype: object

# %%
peoples.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, a to y
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     3 non-null      float64
#  2   addr    3 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 192.0+ bytes

# %%
peoples.count()
# Out:
# name    4
# age     3
# addr    3
# dtype: int64

# %%
peoples.shape
peoples.index
# Out:
# Index(['a', 'b', 'c', 'd', 'x', 'y'], dtype='object')
