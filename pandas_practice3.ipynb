# %%
import pandas as pd
testdf = pd.DataFrame({
    'roll_no': [ 102, 101, 104, 105, 103],
    'name' : ['Kamal', 'Saima', 'Jamal','Farzana', 'Shaikh'],
    'gender' : ['M', 'F', 'M', 'M', 'F'],
    'grade'  : ['A', 'A', 'B', 'B', 'A'],
    'marks'  : [ 21,  23,  12,  14,  20],
    'city' : ['Lahore', 'Peshawer', 'Lahore', 'Karachi', 'Peshawer']
})

testdf
# Out:
#    roll_no     name gender grade  marks      city
# 0      102    Kamal      M     A     21    Lahore
# 1      101    Saima      F     A     23  Peshawer
# 2      104    Jamal      M     B     12    Lahore
# 3      105  Farzana      M     B     14   Karachi
# 4      103   Shaikh      F     A     20  Peshawer

# %%
testdf.loc[(testdf.city == 'Lahore') & (testdf.grade == 'A')]
# Out:
#    roll_no   name gender grade  marks    city
# 0      102  Kamal      M     A     21  Lahore

# %%
testdf.set_index(['roll_no']).sort_index(axis = 0)
# Out:
#             name gender grade  marks      city
# roll_no
# 101        Saima      F     A     23  Peshawer
# 102        Kamal      M     A     21    Lahore
# 103       Shaikh      F     A     20  Peshawer
# 104        Jamal      M     B     12    Lahore
# 105      Farzana      M     B     14   Karachi

# %%
testdf
# Out:
#    roll_no     name gender grade  marks      city
# 0      102    Kamal      M     A     21    Lahore
# 1      101    Saima      F     A     23  Peshawer
# 2      104    Jamal      M     B     12    Lahore
# 3      105  Farzana      M     B     14   Karachi
# 4      103   Shaikh      F     A     20  Peshawer

# %%
df = pd.read_csv('classmarks.csv')
df
# Out:
#    rollno  gender    group   age  math  english  urdu
# 0    MS01  female  group B  28.0  72.0       72  74.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 2    MS03  female  group B  21.0   NaN       95  93.0
# 3    MS04    male  group A  44.0  47.0       57  44.0
# 4    MS05    male  group C  54.0  76.0       78   NaN
# 5    MS06  female  group B   NaN  71.0       83  78.0
# 6    MS07  female  group B  47.0  88.0       95  92.0
# 7    MS08    male  group B  33.0  40.0       43  39.0
# 8    MS09    male  group D  27.0  64.0       64  67.0
# 9    MS10  female  group B  33.0  38.0       60  50.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 11   MS12    male  group D  53.0  40.0       52  43.0
# 12   MS13  female  group B  25.0  65.0       81  73.0
# 13   MS14    male  group A  26.0  78.0       72  70.0
# 14   MS15  female  group A  25.0  50.0       53  58.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# ...

# %%
df.urdu.isna().sum()
# Out:
# 0

# %%
df.english = df['english'].astype('float64') #change the datatype tp float64b
df.dtypes
# Out:
# rollno      object
# gender      object
# group       object
# age        float64
# math       float64
# english    float64
# urdu       float64
# dtype: object

# %%
df.math.mean()
# Out:
# 62.06382978723404

# %%
#df.loc[(df.math.isna(),'math')] = df.math.mean()
df.loc[(df.urdu.isna(),'urdu')] = df.urdu.mean()

# %%
df['age'].isna().sum()
# Out:
# 0

# %%
df2 = pd.read_csv('classmarks.csv')
df2.isna().sum()
# Out:
# rollno     0
# gender     0
# group      0
# age        3
# math       3
# english    0
# urdu       3
# dtype: int64

# %%
df3 = df2
df3
# Out:
#    rollno  gender    group   age  math  english  urdu
# 0    MS01  female  group B  28.0  72.0       72  74.0
# 1    MS02  female  group C  33.0  69.0       90  88.0
# 2    MS03  female  group B  21.0  47.0       95  93.0
# 3    MS04    male  group A  44.0  47.0       57  44.0
# 4    MS05    male  group C  54.0  76.0       78  78.0
# 5    MS06  female  group B  47.0  71.0       83  78.0
# 6    MS07  female  group B  47.0  88.0       95  92.0
# 7    MS08    male  group B  33.0  40.0       43  39.0
# 8    MS09    male  group D  27.0  64.0       64  67.0
# 9    MS10  female  group B  33.0  38.0       60  50.0
# 10   MS11    male  group C  46.0  58.0       54  52.0
# 11   MS12    male  group D  53.0  40.0       52  43.0
# 12   MS13  female  group B  25.0  65.0       81  73.0
# 13   MS14    male  group A  26.0  78.0       72  70.0
# 14   MS15  female  group A  25.0  50.0       53  58.0
# 15   MS16  female  group C  29.0  69.0       75  78.0
# ...

# %%
df4 = pd.get_dummies(df3[['gender']], drop_first = True)
df4
# Out:
#     gender_male
# 0             0
# 1             0
# 2             0
# 3             1
# 4             1
# 5             0
# 6             0
# 7             1
# 8             1
# 9             0
# 10            1
# 11            1
# 12            0
# 13            1
# 14            0
# 15            0
# 16            1
# 17            0
# 18            1
# 19            0
# 20            1
# 21            0
# 22            1
# 23            0
# 24            1
# 25            1
# 26            1
# 27            0
# 28            1
# 29            0
# 30            0
# 31            0
# 32            0
# 33            1
# 34            1
# 35            1
# 36            0
# 37            0
# 38            0
# 39            1
# 40            1
# 41            0
# 42            0
# 43            1
# 44            0
# 45            1
# 46            0
# 47            0
# 48            0
# 49            1

# %%
nd = df3.groupby('gender').age.min()
nd
# Out:
# gender
# female    21.0
# male      22.0
# Name: age, dtype: float64

# %%
df.agg(['min','max','std','var'])
# Out:
#     rollno  gender    group        age        math     english        urdu
# min   MS01  female  group A  21.000000   18.000000   32.000000   28.000000
# max   MS50    male  group E  54.000000   97.000000   95.000000   93.000000
# std    NaN     NaN      NaN   7.641728   14.243372   14.148902   14.495601
# var    NaN     NaN      NaN  58.396005  202.873643  200.191429  210.122449

# %%
def addTwo(x):
    return x + 2

s = df2.english.apply(lambda a: a+3)

# %%
df2['english'] = s
df2
# Out:
#    rollno  gender    group   age  math  english  urdu
# 0    MS01  female  group B  28.0  72.0       75  74.0
# 1    MS02  female  group C  33.0  69.0       93  88.0
# 2    MS03  female  group B  21.0  47.0       98  93.0
# 3    MS04    male  group A  44.0  47.0       60  44.0
# 4    MS05    male  group C  54.0  76.0       81  78.0
# 5    MS06  female  group B  47.0  71.0       86  78.0
# 6    MS07  female  group B  47.0  88.0       98  92.0
# 7    MS08    male  group B  33.0  40.0       46  39.0
# 8    MS09    male  group D  27.0  64.0       67  67.0
# 9    MS10  female  group B  33.0  38.0       63  50.0
# 10   MS11    male  group C  46.0  58.0       57  52.0
# 11   MS12    male  group D  53.0  40.0       55  43.0
# 12   MS13  female  group B  25.0  65.0       84  73.0
# 13   MS14    male  group A  26.0  78.0       75  70.0
# 14   MS15  female  group A  25.0  50.0       56  58.0
# 15   MS16  female  group C  29.0  69.0       78  78.0
# ...

# %%
df2.groupby('group').math.agg(['min','max'])
# Out:
#           min   max
# group
# group A  47.0  78.0
# group B  18.0  88.0
# group C  46.0  88.0
# group D  40.0  75.0
# group E  56.0  97.0

# %%
df.describe()
# Out:
#              age       math    english       urdu
# count  50.000000  50.000000  50.000000  50.000000
# mean   34.276596  62.063830  67.820000  66.000000
# std     7.641728  14.243372  14.148902  14.495601
# min    21.000000  18.000000  32.000000  28.000000
# 25%    29.000000  55.000000  57.250000  57.000000
# 50%    33.000000  63.500000  70.000000  66.000000
# 75%    37.750000  69.750000  75.000000  75.750000
# max    54.000000  97.000000  95.000000  93.000000

# %%
#df2.gender.value_counts()
df2.gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
#df2.fillna(method = 'ffill', inplace = True)
df2.fillna(method = 'bfill', inplace = True)

# %%
b

# %%
so = pd.read_csv('survey_results_public.csv')
so
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
so.loc[so['Country'] == 'Pakistan', :]
# Out:
#        ResponseId                                         MainBranch  \
# 102           103                     I am a developer by profession
# 242           243                     I am a developer by profession
# 476           477                     I am a developer by profession
# 535           536                     I am a developer by profession
# 598           599                     I am a developer by profession
# ...           ...                                                ...
# 83140       83141                     I am a developer by profession
# 83214       83215                     I am a developer by profession
# 83236       83237  I am not primarily a developer, but I write co...
# 83391       83392             I am a student who is learning to code
# 83431       83432                     I am a developer by profession
#
#                                               Employment   Country US_State  \
# ...

# %%
schema = pd.read_csv('survey_results_schema.csv', index_col = 'qname')
schema
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
schema.loc['Country'].value_counts()
# Out:
# QID6                                                              1
# Where do you live? <span style="font-weight: bolder;">*</span>    1
# True                                                              1
# MC                                                                1
# DL                                                                1
# Name: Country, dtype: int64

# %%
so['Country'].value_counts().count()
# Out:
# 181

# %%
so.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
so2 = pd.read_csv('survey_results_public2022.csv')
so2
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
so2.groupby('Country')['LanguageHaveWorkedWith']

# %%
so2.groupby('Country')['LanguageHaveWorkedWith'].apply(lambda x: x in x.str.contains('Python'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#    1252             try:
# -> 1253                 result = self._python_apply_general(f, self._selected_obj)
#    1254             except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#    1286         """
# -> 1287         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1288
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     819             group_axes = group.axes
# --> 820             res = f(group)
#     821             if not _is_indexed_like(res, group_axes, axis):
#
# C:\Users\ALIHAR~1\AppData\Local\Temp/ipykernel_1476/265242651.py in <lambda>(x)
# ...

# %%
df = pd.read_csv('temperature.csv')
df
# Out:
#          date     city  temperature  humidity
# 0  20/06/2021   Lahore           38        76
# 1  21/06/2021   Lahore           41        80
# 2  22/06/2021   Lahore           39        85
# 3  20/06/2021    Muree           17        71
# 4  21/06/2021    Muree           15        70
# 5  22/06/2021    Muree           18        74
# 6  20/06/2021  Karachi           33        93
# 7  21/06/2021  Karachi           30        91
# 8  22/06/2021  Karachi           35        90

# %%
df.pivot_table(index = 'city', columns = 'date')
# Out:
#           humidity                       temperature
# date    20/06/2021 21/06/2021 22/06/2021  20/06/2021 21/06/2021 22/06/2021
# city
# Karachi         93         91         90          33         30         35
# Lahore          76         80         85          38         41         39
# Muree           71         70         74          17         15         18

# %%
df.pivot(index = 'city',columns = 'date')
# Out:
#         temperature                         humidity
# date     20/06/2021 21/06/2021 22/06/2021 20/06/2021 21/06/2021 22/06/2021
# city
# Karachi          33         30         35         93         91         90
# Lahore           38         41         39         76         80         85
# Muree            17         15         18         71         70         74

# %%
df.pivot_table(index = 'city',columns = 'date')
# Out:
#           humidity                       temperature
# date    20/06/2021 21/06/2021 22/06/2021  20/06/2021 21/06/2021 22/06/2021
# city
# Karachi         93         91         90          33         30         35
# Lahore          76         80         85          38         41         39
# Muree           71         70         74          17         15         18

# %%
df2 = pd.read_csv('temperature2.csv')
df2
# Out:
#          date    city  temperature  humidity
# 0  20/06/2021  Lahore           38        76
# 1  20/06/2021  Lahore           40        75
# 2  21/06/2021  Lahore           39        79
# 3  21/06/2021  Lahore           37        74
# 4  20/06/2021   Muree           15        88
# 5  20/06/2021   Muree           17        90
# 6  21/06/2021   Muree           10        93
# 7  21/06/2021   Muree            8        91

# %%
df3 = df2.pivot_table(index = 'date', columns = 'city', aggfunc = 'min')
df3
# Out:
#            humidity       temperature
# city         Lahore Muree      Lahore Muree
# date
# 20/06/2021       75    88          38    15
# 21/06/2021       74    91          37     8

# %%
df2 = pd.read_csv('sports_gender.csv')
df2
# Out:
#    gender       sport  age  height  weight
# 0    male     cricket   22      72     200
# 1  female     cricket   21      72     130
# 2  female  basketball   23      73     150
# 3    male  basketball   21      75     175
# 4  female     cricket   20      68     170

# %%
df2.pivot_table(index = 'gender', columns = 'sport', margins = True)
# Out:
#               age                        height                      weight  \
# sport  basketball cricket        All basketball    cricket   All basketball
# gender
# female       23.0    20.5  21.333333         73  70.000000  71.0      150.0
# male         21.0    22.0  21.500000         75  72.000000  73.5      175.0
# All          22.0    21.0  21.400000         74  70.666667  72.0      162.5
#
#
# sport      cricket    All
# gender
# female  150.000000  150.0
# male    200.000000  187.5
# All     166.666667  165.0

# %%
df = pd.read_csv('waterneed.csv')
df
# Out:
#     uniq_id    animal  water_need  speed
# 0      1001  elephant         500     20
# 1      1002  elephant         600     25
# 2      1003  elephant         350     29
# 3      1004     tiger         300     60
# 4      1005     tiger         320     65
# 5      1006     tiger         330     70
# 6      1007     tiger         290     69
# 7      1008     tiger         310     72
# 8      1009     zebra         200     75
# 9      1010     zebra         220     77
# 10     1011     zebra         240     72
# 11     1012     zebra         230     80
# 12     1013     zebra         220     82
# 13     1014     zebra         100     79
# 14     1015     zebra          80     76
# 15     1016      lion         420     66
# 16     1017      lion         600     67
# 17     1018      lion         500     68
# 18     1019      lion         390     64
# 19     1020  kangaroo         410     19
# 20     1021  kangaroo         430     22
# 21     1022  kangaroo         410     17

# %%
df.pivot_table(index = 'animal')
# Out:
#               speed  uniq_id  water_need
# animal
# elephant  24.666667   1002.0  483.333333
# kangaroo  19.333333   1021.0  416.666667
# lion      66.250000   1017.5  477.500000
# tiger     67.200000   1006.0  310.000000
# zebra     77.285714   1012.0  184.285714

# %%
df.pivot_table(index = ['animal', 'uniq_id'])
# Out:
#                   speed  water_need
# animal   uniq_id
# elephant 1001        20         500
#          1002        25         600
#          1003        29         350
# kangaroo 1020        19         410
#          1021        22         430
#          1022        17         410
# lion     1016        66         420
#          1017        67         600
#          1018        68         500
#          1019        64         390
# tiger    1004        60         300
#          1005        65         320
#          1006        70         330
#          1007        69         290
#          1008        72         310
# zebra    1009        75         200
#          1010        77         220
#          1011        72         240
#          1012        80         230
#          1013        82         220
#          1014        79         100
#          1015        76          80

# %%
so2.loc[so2.Country == 'Pakistan', 'LearnCode'].value_counts()
# Out:
# School (i.e., University, College, etc)                                                                                                                                              47
# Other online resources (e.g., videos, blogs, forum)                                                                                                                                  40
# Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification                                                          37
# Other online resources (e.g., videos, blogs, forum);Online Courses or Certification                                                                                                  31
# Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification                                   28
# ...
